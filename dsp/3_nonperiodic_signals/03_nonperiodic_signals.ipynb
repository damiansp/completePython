# %%
# %load_ext autoreload
# %autoreload 2

# %%
#234567890#234567890#234567890#234567890#234567890#234567890#234567890#23456789
import sys

import matplotlib.pyplot as plt

sys.path.append('..')
import thinkdsp as dsp

# %%
signal = dsp.Chirp(start=220, end=880)
wave = signal.make_wave()
wave.play('/tmp/chirp.wav')
# Out:
# Writing /tmp/chirp.wav

# %%
spectrum = wave.make_spectrum()
spectrum.plot()
plt.xlim([0, 1200])
# Out:
# (0.0, 1200.0)

# %%
signal = dsp.ExpoChirp(start=220, end=880)
wave = signal.make_wave()
wave.play('/tmp/expochirp.wav')
# Out:
# Writing /tmp/expochirp.wav

# %%
spectrum = wave.make_spectrum()
spectrum.plot()
plt.xlim([0, 1200])
# Out:
# (0.0, 1200.0)

# %%
signal = dsp.Chirp(start=220, end=440)
wave = signal.make_wave(duration=1, framerate=11025)
wave.play('/tmp/chirp.wav')
spectrum = wave.make_spectrum()
spectrum.plot()
plt.xlim([0, 800])
# Out:
# Writing /tmp/chirp.wav
# (0.0, 800.0)

# %%
spectrogram = wave.make_spectrogram(seg_length=512)
spectrogram.plot(high=1000)
