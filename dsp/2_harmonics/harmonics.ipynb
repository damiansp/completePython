# %%
#234567890#234567890#234567890#234567890#234567890#234567890#234567890#23456789
import sys

import matplotlib.pyplot as plt
import numpy as np

sys.path.append('..')
import thinkdsp as dsp

# %% [markdown]
# ### 1. Triangle waves

# %%
signal = dsp.TriangleSignal(200)
signal.plot();

# %%
wave = signal.make_wave(duration=0.5, framerate=10_000)
spectrum = wave.make_spectrum()
spectrum.plot()

# %% [markdown]
# ### 2. Square waves

# %%
signal = dsp.SquareSignal(200)
signal.plot()

# %%
wave = signal.make_wave(duration=0.5, framerate=10_000)
spectrum = wave.make_spectrum()
spectrum.plot()

# %% [markdown]
# ### 3. Aliasing

# %%
framerate = 10_000
signal = dsp.CosSignal(4500)
duration = 5 * signal.period
segment = signal.make_wave(duration, framerate=framerate)
segment.plot()

#xv = np.linspace(0, 0.0001, 100)
#yv = np.cos(5 * 4500 * xv)
#plt.plot(xv, yv);

# %%
signal = dsp.CosSignal(5500)
segment = signal.make_wave(duration, framerate=framerate)
segment.plot()

#yv = np.cos(5 * 5500 * xv)
#plt.plot(xv, yv);
