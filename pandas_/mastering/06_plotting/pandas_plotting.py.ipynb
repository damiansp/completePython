# %%
import numpy as np
import pandas as pd

# %%
cars = pd.DataFrame({
    'mpg': [21, 21, 22.8, 21.4, 18.7, 18.1, 18.3, 24.4, 22.8, 19.2],
    'cyl': [6, 6, 4, 6, 8, 6, 8, 4, 4, 4], 
    'disp': [160, 160, 108, 258, 360, 225, 360, 146.7, 140.8, 167.7], 
    'hp': [110, 110, 93, 110, 175, 105, 245, 62, 95, 123],    
    'category':[
        'SUV', 'Sedan', 'Sedan', 'Hatchback', 'SUV', 'Sedan', 'SUV',
        'Hatchback', 'SUV', 'Sedan']}) 
cars
# Out:
#     mpg  cyl   disp   hp   category
# 0  21.0    6  160.0  110        SUV
# 1  21.0    6  160.0  110      Sedan
# 2  22.8    4  108.0   93      Sedan
# 3  21.4    6  258.0  110  Hatchback
# 4  18.7    8  360.0  175        SUV
# 5  18.1    6  225.0  105      Sedan
# 6  18.3    8  360.0  245        SUV
# 7  24.4    4  146.7   62  Hatchback
# 8  22.8    4  140.8   95        SUV
# 9  19.2    4  167.7  123      Sedan

# %%
pd.plotting.andrews_curves(cars, 'category');

# %%
cars['mpg_sq'] = cars.mpg ** 2
pd.plotting.parallel_coordinates(cars, 'category');

# %%
pd.plotting.radviz(cars, 'category');

# %%
pd.plotting.scatter_matrix(cars);

# %%
ts = [1]
for i in range(100):
    ts.append(0.6 * ts[i] + np.random.normal(size=1)[0])

# %%
pd.plotting.lag_plot(pd.Series(ts));

# %%
pd.plotting.lag_plot(pd.Series(np.random.uniform(size=100)));

# %%
pd.plotting.bootstrap_plot(pd.Series(np.random.normal(size=100)));
