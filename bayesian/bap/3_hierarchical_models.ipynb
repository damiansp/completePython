# %%
#234567890#234567890#234567890#234567890#234567890#234567890#234567890#23456789
import numpy as np
import pandas as pd
import pymc as pm

# %%
tips = pd.read_csv(
    'https://raw.githubusercontent.com/aloctavodia/BAP3/refs/heads/main/code/'
    'data/tips.csv')
display(tips.head())

categories = np.array(['Thur', 'Fri', 'Sat', 'Sun'])
tip = tips.tip.values
idx = pd.Categorical(tips.day, categories=categories).codes
coords = {'days': categories, 'days_flat': categories[idx]}
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
with pm.Model(coords=coords) as cs_nh:
    µ = pm.Normal('µ', mu=0, sigma=10, dims='aa')
    sig = pm.HalfNormal('sig', sigma=10, dims='aa')
    y = pm.Normal('y', mu=µ[idx], sigma=sig[idx], observed=diff)
    idata_cs_nh = pm.sample()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 with pm.Model(coords=coords) as cs_nh:
# ----> 2     µ = pm.Normal('µ', mu=0, sigma=10, dims='aa')
#       3     sig = pm.HalfNormal('sig', sigma=10, dims='aa')
#       4     y = pm.Normal('y', mu=µ[idx], sigma=sig[idx], observed=diff)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymc/distributions/distribution.py:525, in Distribution.__new__(cls, name, rng, dims, initval, observed, total_size, transform, default_transform, *args, **kwargs)
#     523 if kwargs.get("size") is None and kwargs.get("shape") is None:
#     524     if dims is not None:
# --> 525         kwargs["shape"] = shape_from_dims(dims, model)
#     526     elif observed is not None:
#     527         kwargs["shape"] = tuple(observed.shape)
#
# ...
