# %% [markdown]
# ### Overriding Methods

# %%
class Bird:
    def __init__(self):
        self.hungry = True
    
    def eat(self):
        if self.hungry:
            print('Nom nom nom')
            self.hungry = False
        else:
            print('Full, thanks')

# %%
b = Bird()
b.eat()
# Out:
# Nom nom nom

# %%
b.eat()
# Out:
# Full, thanks

# %%
class SongBird(Bird):
    def __init__(self):
        self.sound = 'Squawk!'
        
    def sing(self):
        print(self.sound)

# %%
sb = SongBird()
sb.sing()
# Out:
# Squawk!

# %%
sb.eat()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-05f67b3cf162> in <module>()
# ----> 1 sb.eat()
#
# <ipython-input-1-6605bce97e29> in eat(self)
#       4
#       5     def eat(self):
# ----> 6         if self.hungry:
#       7             print('Nom nom nom')
#       8             self.hungry = False
#
# AttributeError: 'SongBird' object has no attribute 'hungry'

# %%
class SongBird(Bird):
    def __init__(self):
        Bird.__init__(self)
        self.sound = 'Warble warble'
    
    def sing(self):
        print(self.sound)

# %%
sb = SongBird()
sb.sing()
# Out:
# Warble warble

# %%
sb.eat()
# Out:
# Nom nom nom

# %%
sb.eat()
# Out:
# Full, thanks

# %%
class SongBird(Bird):
    def __init__(self):
        super(SongBird, self).__init__()
        self.sound = 'Cackaw caw'

    def sing(self):
        print(self.sound)

# %%
sb = SongBird()
sb.sing()
# Out:
# Cackaw caw

# %%
sb.eat()
sb.eat()
# Out:
# Nom nom nom
# Full, thanks

# %% [markdown]
# # Item Access

# %%
def check_index(key):
    if not isinstance(key, int): raise TypeError
    if key < 0: raise IndexError

# %%
class ArithmeticSequence:
    def __init__(self, start=0, step=1):
        self.start = start
        self.step = step
        self.changed = {}
        
    def __getitem__(self, key):
        check_index(key)
        try: return self.changed[key]
        except KeyError: return self.start + key * self.step
        
    def __setitem__(self, key, value):
        check_index(key)
        self.changed[key] = value

# %%
s = ArithmeticSequence(1, 2)

# %%
s[4]
# Out:
# 9

# %%
s[3]
# Out:
# 7

# %%
s[3] = 3

# %%
s[3]
# Out:
# 3

# %%
s[4]
# Out:
# 9
