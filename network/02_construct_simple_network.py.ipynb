# %%
import matplotlib.pyplot as plt
import networkx as nx

# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 10]

# %%
# Types of Graphs

# G = nx.Graph()   # undirected
# D = nx.DiGraph() # directed
# U = nx.Graph(D)  # "undirect"
# M = nx.MultiGraph()   # multiple undirected edges between nodes
# N = nx.MultiDiGraph() # multiple directed

# %%
G = nx.Graph([('A', 'eggs')])
G.add_node('spinach')
G.add_node('Hg')
G.add_nodes_from(['folates', 'asparagus', 'liver'])
G.add_edge('spinach', 'folates')
G.add_edge('spinach', 'heating oil')
G.add_edge('liver', 'Se')
G.add_edges_from([('folates', 'liver'), ('folates', 'asparagus')])

# %%
G.remove_node('Hg')
G.remove_nodes_from(['Hg'])
G.remove_edge('spinach', 'heating oil')
G.remove_edges_from([('spinach', 'heating oil')])
G.remove_node('heating oil')

# %%
# G.clear() # removes all nodes and edges

# %%
G.nodes()
# Out:
# ['A', 'eggs', 'spinach', 'folates', 'asparagus', 'liver', 'Se']

# %%
repr(G.nodes())
# Out:
# "['A', 'eggs', 'spinach', 'folates', 'asparagus', 'liver', 'Se']"

# %%
G.edges()
# Out:
# [('A', 'eggs'),
#  ('spinach', 'folates'),
#  ('folates', 'liver'),
#  ('folates', 'asparagus'),
#  ('liver', 'Se')]

# %%
G.nodes(data=True)
# Out:
# [('A', {}),
#  ('eggs', {}),
#  ('spinach', {}),
#  ('folates', {}),
#  ('asparagus', {}),
#  ('liver', {}),
#  ('Se', {})]

# %%
nx.draw_networkx(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-cea9b642bbe2> in <module>()
# ----> 1 nx.draw_networkx(G)
#
# /usr/local/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     274
#     275     node_collection = draw_networkx_nodes(G, pos, **kwds)
# --> 276     edge_collection = draw_networkx_edges(G, pos, arrows=arrows, **kwds)
#     277     if with_labels:
#     278         draw_networkx_labels(G, pos, **kwds)
#
# /usr/local/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, **kwds)
#     520         lw = width
#     521
# --> 522     if not cb.is_string_like(edge_color) \
#     523            and cb.iterable(edge_color) \
#     524            and len(edge_color) == len(edge_pos):
#
# AttributeError: module 'matplotlib.cbook' has no attribute 'is_string_like'
