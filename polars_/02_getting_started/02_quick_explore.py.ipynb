# %%
from datetime import datetime, timedelta

import numpy as np
import polars as pl

# %%
series = pl.Series('a', [1, 2, 3, 4, 5])
series
# Out:
# shape: (5,)
# Series: 'a' [i64]
# [
# 	1
# 	2
# 	3
# 	4
# 	5
# ]

# %%
series = pl.Series([1, 2, 3, 4, 5])
series
# Out:
# shape: (5,)
# Series: '' [i64]
# [
# 	1
# 	2
# 	3
# 	4
# 	5
# ]

# %%
df = pl.DataFrame({
    'id': [1, 2, 3],
    'date':[(datetime(2000, 1, i)) for i in [1, 2, 3]],
    'stuff': [4.3, 5.4, 6.5]})
df
# Out:
# shape: (3, 3)
# ┌─────┬─────────────────────┬───────┐
# │ id  ┆ date                ┆ stuff │
# │ --- ┆ ---                 ┆ ---   │
# │ i64 ┆ datetime[μs]        ┆ f64   │
# ╞═════╪═════════════════════╪═══════╡
# │ 1   ┆ 2000-01-01 00:00:00 ┆ 4.3   │
# │ 2   ┆ 2000-01-02 00:00:00 ┆ 5.4   │
# │ 3   ┆ 2000-01-03 00:00:00 ┆ 6.5   │
# └─────┴─────────────────────┴───────┘

# %%
df.write_csv('polar_test.csv')

# %%
df = pl.read_csv('polar_test.csv')
df
# Out:
# shape: (3, 3)
# ┌─────┬────────────────────────────┬───────┐
# │ id  ┆ date                       ┆ stuff │
# │ --- ┆ ---                        ┆ ---   │
# │ i64 ┆ str                        ┆ f64   │
# ╞═════╪════════════════════════════╪═══════╡
# │ 1   ┆ 2000-01-01T00:00:00.000000 ┆ 4.3   │
# │ 2   ┆ 2000-01-02T00:00:00.000000 ┆ 5.4   │
# │ 3   ┆ 2000-01-03T00:00:00.000000 ┆ 6.5   │
# └─────┴────────────────────────────┴───────┘

# %%
df = pl.read_csv('polar_test.csv', parse_dates=True)
df
# Out:
# shape: (3, 3)
# ┌─────┬─────────────────────┬───────┐
# │ id  ┆ date                ┆ stuff │
# │ --- ┆ ---                 ┆ ---   │
# │ i64 ┆ datetime[μs]        ┆ f64   │
# ╞═════╪═════════════════════╪═══════╡
# │ 1   ┆ 2000-01-01 00:00:00 ┆ 4.3   │
# │ 2   ┆ 2000-01-02 00:00:00 ┆ 5.4   │
# │ 3   ┆ 2000-01-03 00:00:00 ┆ 6.5   │
# └─────┴─────────────────────┴───────┘

# %% [markdown]
# ### Viewing Data

# %%
df = pl.DataFrame({
    'a': np.arange(8),
    'b': np.random.rand(8),
    'c': [datetime(2023, 1, i) for i in range(1, 9)],
    'd': [1, 2.0, np.nan, np.nan, 0, -5, -42, None]})
df
# Out:
# shape: (8, 4)
# ┌─────┬──────────┬─────────────────────┬───────┐
# │ a   ┆ b        ┆ c                   ┆ d     │
# │ --- ┆ ---      ┆ ---                 ┆ ---   │
# │ i64 ┆ f64      ┆ datetime[μs]        ┆ f64   │
# ╞═════╪══════════╪═════════════════════╪═══════╡
# │ 0   ┆ 0.070837 ┆ 2023-01-01 00:00:00 ┆ 1.0   │
# │ 1   ┆ 0.881005 ┆ 2023-01-02 00:00:00 ┆ 2.0   │
# │ 2   ┆ 0.739494 ┆ 2023-01-03 00:00:00 ┆ NaN   │
# │ 3   ┆ 0.287771 ┆ 2023-01-04 00:00:00 ┆ NaN   │
# │ 4   ┆ 0.740038 ┆ 2023-01-05 00:00:00 ┆ 0.0   │
# │ 5   ┆ 0.402342 ┆ 2023-01-06 00:00:00 ┆ -5.0  │
# │ 6   ┆ 0.662465 ┆ 2023-01-07 00:00:00 ┆ -42.0 │
# │ 7   ┆ 0.057387 ┆ 2023-01-08 00:00:00 ┆ null  │
# └─────┴──────────┴─────────────────────┴───────┘

# %%
df.head()
# Out:
# shape: (5, 4)
# ┌─────┬──────────┬─────────────────────┬─────┐
# │ a   ┆ b        ┆ c                   ┆ d   │
# │ --- ┆ ---      ┆ ---                 ┆ --- │
# │ i64 ┆ f64      ┆ datetime[μs]        ┆ f64 │
# ╞═════╪══════════╪═════════════════════╪═════╡
# │ 0   ┆ 0.070837 ┆ 2023-01-01 00:00:00 ┆ 1.0 │
# │ 1   ┆ 0.881005 ┆ 2023-01-02 00:00:00 ┆ 2.0 │
# │ 2   ┆ 0.739494 ┆ 2023-01-03 00:00:00 ┆ NaN │
# │ 3   ┆ 0.287771 ┆ 2023-01-04 00:00:00 ┆ NaN │
# │ 4   ┆ 0.740038 ┆ 2023-01-05 00:00:00 ┆ 0.0 │
# └─────┴──────────┴─────────────────────┴─────┘

# %%
df.sample(3)
# Out:
# shape: (3, 4)
# ┌─────┬──────────┬─────────────────────┬──────┐
# │ a   ┆ b        ┆ c                   ┆ d    │
# │ --- ┆ ---      ┆ ---                 ┆ ---  │
# │ i64 ┆ f64      ┆ datetime[μs]        ┆ f64  │
# ╞═════╪══════════╪═════════════════════╪══════╡
# │ 0   ┆ 0.070837 ┆ 2023-01-01 00:00:00 ┆ 1.0  │
# │ 7   ┆ 0.057387 ┆ 2023-01-08 00:00:00 ┆ null │
# │ 3   ┆ 0.287771 ┆ 2023-01-04 00:00:00 ┆ NaN  │
# └─────┴──────────┴─────────────────────┴──────┘

# %%
df.describe()
# Out:
# shape: (7, 5)
# ┌────────────┬─────────┬──────────┬────────────────────────────┬───────┐
# │ describe   ┆ a       ┆ b        ┆ c                          ┆ d     │
# │ ---        ┆ ---     ┆ ---      ┆ ---                        ┆ ---   │
# │ str        ┆ f64     ┆ f64      ┆ str                        ┆ f64   │
# ╞════════════╪═════════╪══════════╪════════════════════════════╪═══════╡
# │ count      ┆ 8.0     ┆ 8.0      ┆ 8                          ┆ 8.0   │
# │ null_count ┆ 0.0     ┆ 0.0      ┆ 0                          ┆ 1.0   │
# │ mean       ┆ 3.5     ┆ 0.480167 ┆ null                       ┆ NaN   │
# │ std        ┆ 2.44949 ┆ 0.32028  ┆ null                       ┆ NaN   │
# │ min        ┆ 0.0     ┆ 0.057387 ┆ 2023-01-01 00:00:00.000000 ┆ -42.0 │
# │ max        ┆ 7.0     ┆ 0.881005 ┆ 2023-01-08 00:00:00.000000 ┆ 2.0   │
# │ median     ┆ 3.5     ┆ 0.532404 ┆ null                       ┆ 1.0   │
# └────────────┴─────────┴──────────┴────────────────────────────┴───────┘

# %% [markdown]
# ### Expressions

# %%
df.select(pl.col('*'))
# Out:
# shape: (8, 4)
# ┌─────┬──────────┬─────────────────────┬───────┐
# │ a   ┆ b        ┆ c                   ┆ d     │
# │ --- ┆ ---      ┆ ---                 ┆ ---   │
# │ i64 ┆ f64      ┆ datetime[μs]        ┆ f64   │
# ╞═════╪══════════╪═════════════════════╪═══════╡
# │ 0   ┆ 0.070837 ┆ 2023-01-01 00:00:00 ┆ 1.0   │
# │ 1   ┆ 0.881005 ┆ 2023-01-02 00:00:00 ┆ 2.0   │
# │ 2   ┆ 0.739494 ┆ 2023-01-03 00:00:00 ┆ NaN   │
# │ 3   ┆ 0.287771 ┆ 2023-01-04 00:00:00 ┆ NaN   │
# │ 4   ┆ 0.740038 ┆ 2023-01-05 00:00:00 ┆ 0.0   │
# │ 5   ┆ 0.402342 ┆ 2023-01-06 00:00:00 ┆ -5.0  │
# │ 6   ┆ 0.662465 ┆ 2023-01-07 00:00:00 ┆ -42.0 │
# │ 7   ┆ 0.057387 ┆ 2023-01-08 00:00:00 ┆ null  │
# └─────┴──────────┴─────────────────────┴───────┘

# %%
df.select(pl.col(['a', 'b']))
# Out:
# shape: (8, 2)
# ┌─────┬──────────┐
# │ a   ┆ b        │
# │ --- ┆ ---      │
# │ i64 ┆ f64      │
# ╞═════╪══════════╡
# │ 0   ┆ 0.070837 │
# │ 1   ┆ 0.881005 │
# │ 2   ┆ 0.739494 │
# │ 3   ┆ 0.287771 │
# │ 4   ┆ 0.740038 │
# │ 5   ┆ 0.402342 │
# │ 6   ┆ 0.662465 │
# │ 7   ┆ 0.057387 │
# └─────┴──────────┘

# %%
df.select([pl.col('a'), pl.col('b')]).limit(3)
# Out:
# shape: (3, 2)
# ┌─────┬──────────┐
# │ a   ┆ b        │
# │ --- ┆ ---      │
# │ i64 ┆ f64      │
# ╞═════╪══════════╡
# │ 0   ┆ 0.070837 │
# │ 1   ┆ 0.881005 │
# │ 2   ┆ 0.739494 │
# └─────┴──────────┘

# %%
df.select([pl.exclude('a')])
# Out:
# shape: (8, 3)
# ┌──────────┬─────────────────────┬───────┐
# │ b        ┆ c                   ┆ d     │
# │ ---      ┆ ---                 ┆ ---   │
# │ f64      ┆ datetime[μs]        ┆ f64   │
# ╞══════════╪═════════════════════╪═══════╡
# │ 0.070837 ┆ 2023-01-01 00:00:00 ┆ 1.0   │
# │ 0.881005 ┆ 2023-01-02 00:00:00 ┆ 2.0   │
# │ 0.739494 ┆ 2023-01-03 00:00:00 ┆ NaN   │
# │ 0.287771 ┆ 2023-01-04 00:00:00 ┆ NaN   │
# │ 0.740038 ┆ 2023-01-05 00:00:00 ┆ 0.0   │
# │ 0.402342 ┆ 2023-01-06 00:00:00 ┆ -5.0  │
# │ 0.662465 ┆ 2023-01-07 00:00:00 ┆ -42.0 │
# │ 0.057387 ┆ 2023-01-08 00:00:00 ┆ null  │
# └──────────┴─────────────────────┴───────┘
